# %%
import pandas as pd
import math
from math import sqrt
from scipy.stats import norm, t
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import statistics as stat

# %%
datafile = '../../dataset/ch17/swim_the_lake_2016.txt'
swim_the_lake_2016 = pd.read_csv(datafile, sep='\t')

# %%
swim_the_lake_2016.head()
# Out:
#             Name Sex       Age  Start Day Month  Year  Time(min) Direction
# 0   Marilyn Bell   F  16.00000          8   Sep  1954     1255.0        SN
# 1   John Jaremey   M  36.00000         23   Jul  1956     1273.0        SN
# 2  Brenda Fisher   F  28.00000         12   Aug  1956     1131.0        SN
# 3     Bill Sadlo   M  57.31781         23   Aug  1957     1501.0        SN
# 4      Jim Woods   M  41.00000         26   Aug  1957     1115.0        SN

# %%
swim_the_lake_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       62 non-null     object
#  1   Sex        62 non-null     object
#  2   Age        62 non-null     float64
#  3   Start Day  62 non-null     int64
#  4   Month      62 non-null     object
#  5   Year       62 non-null     int64
#  6   Time(min)  62 non-null     float64
#  7   Direction  62 non-null     object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.0+ KB

# %%
len(swim_the_lake_2016)
# Out:
# 62

# %%
swim_the_lake_2016.columns
# Out:
# Index(['Name', 'Sex', 'Age', 'Start Day', 'Month', 'Year', 'Time(min)',
#        'Direction'],
#       dtype='object')

# %%
swim_the_lake_2016.index
# Out:
# RangeIndex(start=0, stop=62, step=1)

# %%
swim_the_lake_2016[swim_the_lake_2016.Name=='Vicki Keith']
# Out:
#            Name Sex   Age  Start Day Month  Year  Time(min) Direction
# 22  Vicki Keith   F  25.0         14   Aug  1986     1619.0        NS
# 23  Vicki Keith   F  26.0          5   Aug  1987     3370.0       NSN
# 24  Vicki Keith   F  27.0         29   Aug  1988     1413.0        SN
# 27  Vicki Keith   F  28.0          3   Sep  1989     1860.0        SN

# %%
swim_the_lake_2016 = swim_the_lake_2016.drop(index=23)

# %%
len(swim_the_lake_2016)
# Out:
# 61

# %%
plt.figure(figsize=(1, 3))
sns.boxplot(data=swim_the_lake_2016, x='Sex', y='Time(min)');

# %%
F = swim_the_lake_2016[swim_the_lake_2016.Sex=='F']['Time(min)']
M = swim_the_lake_2016[swim_the_lake_2016.Sex=='M']['Time(min)']

# %%
plt.hist(F, bins=range(750, 2001, 250), edgecolor='k');
plt.xticks(range(750, 2001, 250));

# %%
plt.hist(M, bins=range(750, 2501, 250), edgecolor='k');
plt.xticks(range(750, 2501, 250));

# %%
def iqr(data):
    q75, q25 = np.percentile(data, [75, 25])
    return q75, q25, q75-q25

# %%
_q75, _q25, f_iqr = iqr(F)
_q75, _q25, m_iqr = iqr(M)

summary_of_swim_the_lake_2016= pd.DataFrame(
data={

    'Count': [ len(F),
               len(M)  
             ],
    
    'Mean': [round(stat.mean(F), 2),
             round(stat.mean(M), 2)
            ],
    

    'StdDev':[round(stat.stdev(F), 3),
              round(stat.stdev(M), 3)
            ],
    
     },
    
    index=['F', 'M']
)

summary_of_swim_the_lake_2016
# Out:
#    Count     Mean   StdDev
# F     36  1262.08  254.701
# M     25  1226.29  368.022

# %% [markdown]
# **Problem 79.** Swim the lake 2016 revisited As we saw in Chapter 8, Exer- cise 46, between 1954 and 2016, swimmers have crossed Lake Ontario 62 times. Both women and men have made the crossing. Here are some plots (we’ve omitted a crossing by Vikki Keith, who swam a round trip—north to south to north—in 3390 minutes):
#
# Is there a difference between the mean amount of time (in minutes) it takes female and male swimmers to swim the lake?
#
# a) Construct and interpret a 95% confidence interval for the difference between female and male crossing times (technology gives 39 df).
#
# b) Find the P-value for the appropriate hypothesis test.
#
# c) Comment on the assumptions and conditions and your conclusions.

# %%
def sol79a():
    n_female = 36
    n_male = 25
    
    y_bar_female = 1262.08
    y_bar_male = 1226.29
    
    s_female = 254.701
    s_male = 368.022

    df = 39

    SE = sqrt ((s_female ** 2 / n_female) + (s_male ** 2 / n_male) )
    
    observed_diff = y_bar_female - y_bar_male
    tcritical = t.ppf(0.975, df)

    print(f"observed_diff: {observed_diff:.2f}")
    print(f"SE: {SE:.2f}")
    print (f"tcritical: {tcritical:.2f}")
    print(f"95% CI: ({(observed_diff-SE*tcritical):.2f}, {(observed_diff+SE*tcritical):.2f})")

sol79a()
# Out:
# observed_diff: 35.79
# SE: 84.97
# tcritical: 2.02
# 95% CI: (-136.07, 207.65)

# %% [markdown]
# **Answer to 79(a)**
#
# The 95% confidence interval for the difference between female and male crossing time is (-136.07, 207.65).  I am 95% confident that the mean crossing time of female is in between 136.07 less and 207.65 more than the mean time for male to cross the Lake Ontario.  However, the CI includes 0, and we may not too sure for the difference between the crossing time of female and the male's.

# %%
def sol79b():

    n_female = 36
    n_male = 25
    
    y_bar_female = 1262.08
    y_bar_male = 1226.29
    
    s_female = 254.701
    s_male = 368.022

    df = 39

    SE = sqrt ((s_female ** 2 / n_female) + (s_male ** 2 / n_male) )
    
    observed_diff = y_bar_female - y_bar_male
    tscore = observed_diff / SE
    
    pval = (1 - t.cdf(tscore, df)) * 2
    print(f"observed_diff: {observed_diff:.2f}")
    print(f"SE: {SE:.2f}")
    print (f"tscore: {tscore:.2f}")
    print (f"pval: {pval:.3f}")

sol79b()
# Out:
# observed_diff: 35.79
# SE: 84.97
# tscore: 0.42
# pval: 0.676

# %% [markdown]
# **Answer to 79(b)**
#
# The p-value is 0.6620, which is high, and we fail to reject the null hypothesis of $\mu_F - \mu_M = 0$.

# %% [markdown]
# **Answer to 79(c)**
#
# Randomization condition: Not from a random sample.
#
# <font color="red">Source of randomness: Sampler has no control over the swimmers' participation.  The sampler is a indifferent bystander.  What affects the swimming time?  The atheletes' strength and performance, weather and tides, water temperature, etc.
#  The sampler has no control over the factors.  The sample can be considered random.</font>
#
# Independent groups assumption: The swimmers should be independent.
#
# Nearly Normal condition: The boxplot and the histograms show the male group has outliers, and we should remove the outliers and test again.  The histograms of the two groups are reasonably unimodal and symmetric.
#
# <font color="red">Sample sizes are 36 and 25, respectively.  These are not large samples.  Although we may pretent to use normal population assumption for an initial attempt at the analysis, normality may be questionable.</font>

# %% [markdown]
# **Problem 80.**  Still swimming Here’s some additional information about the Ontario crossing times presented in Exercise 79. It is generally thought to be harder to swim across the lake from north to south. Indeed, this has been done only 5 times. Every one of those crossings was by a woman. If we omit those 5 crossings, the boxplots look like this:
#
# Although not designated as an outlier, the slowest female time belongs to Vikki Keith, who crossed the lake swimming only butterfly stroke. Omitting that extraordinary swim gives the following summary statistics:
#
# a) Do women or men appear to be faster at swimming across the lake? Support your answer by interpreting a confidence interval. (Use 37 df.)
#
# b) Some might argue that the men are being unfairly slowed down by two extraordinarily slow swims. Here are the sum- maries without those two swims. Repeat part a based on these data. Does your conclusion change? (Use 47 df.)
#
# c) Vikki Keith was responsible for two of the more remarkable crossings, but she also swam Lake Ontario two other times. In fact, of the 50 crossings in this analysis, 7 were repeat crossings by a swimmer who’d crossed the lake before. How does this fact affect your thoughts about the confidence interval?

# %%
datafile = '../../dataset/ch17/swim_the_lake_2016.txt'
swim_the_lake = pd.read_csv(datafile, sep='\t')

# %%
swim_the_lake.head(n=50)
# Out:
#                   Name Sex       Age  Start Day Month  Year  Time(min)  \
# 0         Marilyn Bell   F  16.00000          8   Sep  1954     1255.0
# 1         John Jaremey   M  36.00000         23   Jul  1956     1273.0
# 2        Brenda Fisher   F  28.00000         12   Aug  1956     1131.0
# 3           Bill Sadlo   M  57.31781         23   Aug  1957     1501.0
# 4            Jim Woods   M  41.00000         26   Aug  1957     1115.0
# 5            Jim Woods   M  45.00000          2   Sep  1961     1027.0
# 6       Cindy Nicholas   F  16.00000         17   Aug  1974      910.0
# 7           Diana Nyad   F  24.00000         30   Aug  1974     1095.0
# 8         Debbie Roach   F  17.00000         16   Aug  1975     1110.0
# 9       Angela Kondrak   F  17.00000         22   Aug  1976     1428.0
# 10         Kim Lumsdon   F  19.00000         27   Aug  1976     1287.0
# 11       John Kinsella   M  25.00000         16   Aug  1978      829.0
# 12        Claudio Plit   M  23.00000         16   Aug  1978      901.0
# 13     Raul Villagomez   M  27.00000         16   Aug  1978      909.0
# 14       Magdy Mandour   M  23.00000         16   Aug  1978      919.0
# 15          Bill Heiss   M  26.00000         16   Aug  1978      957.0
# 16    Loreen Passfield   F  21.00000          1   Sep  1979      943.0
# 17        Jocelyn Muir   F  15.00000          5   Sep  1981      955.0
# 18    Marilyn Korzekwa   F  26.00000          1   Sep  1983     1289.0
# 19          Cam Kamula   M  29.00000          3   Aug  1984     1207.0
# 20    Marilyn Korzekwa   F  27.00000         17   Aug  1984     1283.0
# 21       Kim Middleton   F  26.00000         16   Aug  1985     1114.0
# 22         Vicki Keith   F  25.00000         14   Aug  1986     1619.0
# 23         Vicki Keith   F  26.00000          5   Aug  1987     3370.0
# 24         Vicki Keith   F  27.00000         29   Aug  1988     1413.0
# 25           Rick Wood   M  31.00000         19   Aug  1989     1293.0
# 26            Bob Weir   M  46.00000         23   Aug  1989     1328.0
# 27         Vicki Keith   F  28.00000          3   Sep  1989     1860.0
# 28         Paolo Pinto   M  52.00000         28  July  1990     1437.0
# 29     Colleen Shields   F  38.00000         10   Aug  1990     1076.0
# 30      Patty Thompson   F  45.00000         14   Aug  1991     1158.0
# 31          John Scott   M  31.00000          7   Aug  1992      890.0
# 32        Carlos Costa   M  20.00000         22  July  1993     1963.0
# 33    Shelagh Freedman   F  17.00000         12   Aug  1993     1563.0
# 34       Kim Middleton   F  34.00000          4   Sep  1993     1740.0
# 35       Kim Middleton   F  35.00000         30  July  1994     1574.0
# 36          John Scott   M  33.00000          7   Aug  1994      882.0
# 37        Rick Goodwin   M  36.00000         27   Aug  1994     1626.0
# 38       Ingrid Martin   F  38.00000         11   Aug  1996     1405.0
# 39    Paula Stephanson   F  17.00000         16   Aug  1996     1360.0
# 40     Nicole Mallette   F  31.00000          8   Aug  1997      970.0
# 41          Dan Foster   M  33.00000         15   Aug  1998     1152.0
# 42        Gregg Taylor   M  19.00000         13   Aug  2003     1163.0
# 43         Peter Gibbs   M  56.00000          7   Aug  2004     1120.0
# 44   Melissa Brannagan   F  23.00000          9   Aug  2005      971.0
# 45         Kim Lumsdon   F  49.00000          5   Aug  2006     1598.0
# 46  Samantha Whiteside   F  16.00000          8   Aug  2006      912.0
# 47     Colleen Shields   F  54.00000         12   Aug  2006      991.0
# 48   Stephanie Hermans   F  21.00000         10   Aug  2007     1085.0
# 49         Jay Serdula   M  35.00000         28  July  2008     2461.0
#
#    Direction
# 0         SN
# 1         SN
# 2         SN
# 3         SN
# 4         SN
# 5         SN
# 6         SN
# 7         NS
# 8         SN
# 9         SN
# 10        SN
# 11        SN
# 12        SN
# 13        SN
# 14        SN
# 15        SN
# 16        SN
# 17        SN
# 18        SN
# 19        SN
# 20        NS
# 21        SN
# 22        NS
# 23       NSN
# 24        SN
# 25        SN
# 26        SN
# 27        SN
# 28        SN
# 29        SN
# 30        SN
# 31        SN
# 32        SN
# 33        SN
# 34        NS
# 35        NS
# 36        SN
# 37        SN
# 38        SN
# 39        SN
# 40        SN
# 41        SN
# 42        SN
# 43        SN
# 44        SN
# 45        SN
# 46        SN
# 47        SN
# 48        SN
# 49        SN

# %%
swim_the_lake[swim_the_lake.Direction=='NS']
# Out:
#                 Name Sex   Age  Start Day Month  Year  Time(min) Direction
# 7         Diana Nyad   F  24.0         30   Aug  1974     1095.0        NS
# 20  Marilyn Korzekwa   F  27.0         17   Aug  1984     1283.0        NS
# 22       Vicki Keith   F  25.0         14   Aug  1986     1619.0        NS
# 34     Kim Middleton   F  34.0          4   Sep  1993     1740.0        NS
# 35     Kim Middleton   F  35.0         30  July  1994     1574.0        NS

# %%
swim_the_lake = swim_the_lake.drop(index=7)
swim_the_lake = swim_the_lake.drop(index=20)
swim_the_lake = swim_the_lake.drop(index=22)
swim_the_lake = swim_the_lake.drop(index=34)
swim_the_lake = swim_the_lake.drop(index=35)
swim_the_lake.head(n=70)
# Out:
#                       Name Sex        Age  Start Day Month  Year  Time(min)  \
# 0             Marilyn Bell   F  16.000000          8   Sep  1954    1255.00
# 1             John Jaremey   M  36.000000         23   Jul  1956    1273.00
# 2            Brenda Fisher   F  28.000000         12   Aug  1956    1131.00
# 3               Bill Sadlo   M  57.317810         23   Aug  1957    1501.00
# 4                Jim Woods   M  41.000000         26   Aug  1957    1115.00
# 5                Jim Woods   M  45.000000          2   Sep  1961    1027.00
# 6           Cindy Nicholas   F  16.000000         17   Aug  1974     910.00
# 8             Debbie Roach   F  17.000000         16   Aug  1975    1110.00
# 9           Angela Kondrak   F  17.000000         22   Aug  1976    1428.00
# 10             Kim Lumsdon   F  19.000000         27   Aug  1976    1287.00
# 11           John Kinsella   M  25.000000         16   Aug  1978     829.00
# 12            Claudio Plit   M  23.000000         16   Aug  1978     901.00
# 13         Raul Villagomez   M  27.000000         16   Aug  1978     909.00
# 14           Magdy Mandour   M  23.000000         16   Aug  1978     919.00
# 15              Bill Heiss   M  26.000000         16   Aug  1978     957.00
# 16        Loreen Passfield   F  21.000000          1   Sep  1979     943.00
# 17            Jocelyn Muir   F  15.000000          5   Sep  1981     955.00
# 18        Marilyn Korzekwa   F  26.000000          1   Sep  1983    1289.00
# 19              Cam Kamula   M  29.000000          3   Aug  1984    1207.00
# 21           Kim Middleton   F  26.000000         16   Aug  1985    1114.00
# 23             Vicki Keith   F  26.000000          5   Aug  1987    3370.00
# 24             Vicki Keith   F  27.000000         29   Aug  1988    1413.00
# 25               Rick Wood   M  31.000000         19   Aug  1989    1293.00
# 26                Bob Weir   M  46.000000         23   Aug  1989    1328.00
# 27             Vicki Keith   F  28.000000          3   Sep  1989    1860.00
# 28             Paolo Pinto   M  52.000000         28  July  1990    1437.00
# 29         Colleen Shields   F  38.000000         10   Aug  1990    1076.00
# 30          Patty Thompson   F  45.000000         14   Aug  1991    1158.00
# 31              John Scott   M  31.000000          7   Aug  1992     890.00
# 32            Carlos Costa   M  20.000000         22  July  1993    1963.00
# 33        Shelagh Freedman   F  17.000000         12   Aug  1993    1563.00
# 36              John Scott   M  33.000000          7   Aug  1994     882.00
# 37            Rick Goodwin   M  36.000000         27   Aug  1994    1626.00
# 38           Ingrid Martin   F  38.000000         11   Aug  1996    1405.00
# 39        Paula Stephanson   F  17.000000         16   Aug  1996    1360.00
# 40         Nicole Mallette   F  31.000000          8   Aug  1997     970.00
# 41              Dan Foster   M  33.000000         15   Aug  1998    1152.00
# 42            Gregg Taylor   M  19.000000         13   Aug  2003    1163.00
# 43             Peter Gibbs   M  56.000000          7   Aug  2004    1120.00
# 44       Melissa Brannagan   F  23.000000          9   Aug  2005     971.00
# 45             Kim Lumsdon   F  49.000000          5   Aug  2006    1598.00
# 46      Samantha Whiteside   F  16.000000          8   Aug  2006     912.00
# 47         Colleen Shields   F  54.000000         12   Aug  2006     991.00
# 48       Stephanie Hermans   F  21.000000         10   Aug  2007    1085.00
# 49             Jay Serdula   M  35.000000         28  July  2008    2461.00
# 50          Shaun Chisholm   M  40.000000         10   Aug  2008    1163.00
# 51        Jade Scognamillo   F  15.649315         31  July  2009    1199.00
# 52        Susanne Robinson   F  36.000000         10   Aug  2010    1468.00
# 53  Miguel Vadillo Sanchez   M  40.000000         10   Aug  2010    1083.00
# 54       Rebekah Boscariol   F  17.000000          5   Aug  2011     933.00
# 55     Christine Arsenault   F  35.000000          8   Aug  2011    1342.00
# 56          Annaleise Carr   F  14.432900         18   Aug  2012    1601.00
# 57        Ashleigh Beacham   F  15.000000         18   Aug  2013    1103.00
# 58       Trinity Arsenault   F  14.046575          3   Aug  2014    1400.00
# 59         Colleen Shields   F  62.903000          8   Aug  2014    1294.00
# 60         Michael McIsaac   M  32.000000         22   Aug  2015    1343.00
# 61              Loren King   M  48.014000          1   Aug  2016    1115.13
#
#    Direction
# 0         SN
# 1         SN
# 2         SN
# 3         SN
# 4         SN
# 5         SN
# 6         SN
# 8         SN
# 9         SN
# 10        SN
# 11        SN
# 12        SN
# 13        SN
# 14        SN
# 15        SN
# 16        SN
# 17        SN
# 18        SN
# 19        SN
# 21        SN
# 23       NSN
# 24        SN
# 25        SN
# 26        SN
# 27        SN
# 28        SN
# 29        SN
# 30        SN
# 31        SN
# 32        SN
# 33        SN
# 36        SN
# 37        SN
# 38        SN
# 39        SN
# 40        SN
# 41        SN
# 42        SN
# 43        SN
# 44        SN
# 45        SN
# 46        SN
# 47        SN
# 48        SN
# 49        SN
# 50        SN
# 51        SN
# 52        SN
# 53        SN
# 54        SN
# 55        SN
# 56        SN
# 57        SN
# 58        SN
# 59        SN
# 60        SN
# 61        SN

# %%
swim_the_lake[swim_the_lake.Name=='Vicki Keith']
# Out:
#            Name Sex   Age  Start Day Month  Year  Time(min) Direction
# 23  Vicki Keith   F  26.0          5   Aug  1987     3370.0       NSN
# 24  Vicki Keith   F  27.0         29   Aug  1988     1413.0        SN
# 27  Vicki Keith   F  28.0          3   Sep  1989     1860.0        SN

# %%
swim_the_lake = swim_the_lake.drop(index=23)
swim_the_lake = swim_the_lake.drop(index=27)  # slowest female time, although not an outlier

# %%
plt.figure(figsize=(1, 3))
sns.boxplot(data=swim_the_lake, x='Sex', y='Time(min)');

# %%
F = swim_the_lake[swim_the_lake.Sex=='F']['Time(min)']
M = swim_the_lake[swim_the_lake.Sex=='M']['Time(min)']

# %%
len(F), len(M)
# Out:
# (30, 25)

# %%
_q75, _q25, f_iqr = iqr(F)
_q75, _q25, m_iqr = iqr(M)

summary_of_swim_the_lake= pd.DataFrame(
data={

    'Count': [ len(F),
               len(M)  
             ],
    
    'Mean': [round(stat.mean(F), 2),
             round(stat.mean(M), 2)
            ],
    

    'StdDev':[round(stat.stdev(F), 3),
              round(stat.stdev(M), 3)
            ],
    
     },
    
    index=['F', 'M']
)

summary_of_swim_the_lake
# Out:
#    Count     Mean   StdDev
# F     30  1208.80  215.473
# M     25  1226.29  368.022

# %%
def sol80a():
    n_female = 30
    n_male = 25
    
    y_bar_female = 1208.80
    y_bar_male = 1226.29
    
    s_female = 215.473
    s_male = 368.022

    df = 37
    
    SE = sqrt ((s_female ** 2 / n_female) + (s_male ** 2 / n_male) )
    
    observed_diff = y_bar_female - y_bar_male
    tcritical = t.ppf(0.975, df)

    print(f"observed_diff: {observed_diff:.2f}")
    print(f"SE: {SE:.2f}")
    print (f"tcritical: {tcritical:.2f}")
    print(f"95% CI: ({(observed_diff-SE*tcritical):.2f}, {(observed_diff+SE*tcritical):.2f})")

sol80a()
# Out:
# observed_diff: -17.49
# SE: 83.46
# tcritical: 2.03
# 95% CI: (-186.59, 151.61)

# %% [markdown]
# **80(a) answer**
#
# The 95% confidence interval is (-186.59, 151.61).  I am 95% confident that the mean crossing time of female is 186.59 less and 151.61 more than the mean time for male to cross the Lake Ontario. However, the CI includes 0, and we may not too sure which group is faster.

# %%
swim_the_lake[swim_the_lake.Name=='Jay Serdula']
# Out:
#            Name Sex   Age  Start Day Month  Year  Time(min) Direction
# 49  Jay Serdula   M  35.0         28  July  2008     2461.0        SN

# %%
swim_the_lake[swim_the_lake.Name=='Carlos Costa']
# Out:
#             Name Sex   Age  Start Day Month  Year  Time(min) Direction
# 32  Carlos Costa   M  20.0         22  July  1993     1963.0        SN

# %%
swim_the_lake = swim_the_lake.drop(index=49)

# %%
swim_the_lake = swim_the_lake.drop(index=32)

# %%
F = swim_the_lake[swim_the_lake.Sex=='F']['Time(min)']
M = swim_the_lake[swim_the_lake.Sex=='M']['Time(min)']

# %%
_q75, _q25, f_iqr = iqr(F)
_q75, _q25, m_iqr = iqr(M)

summary_of_swim_the_lake= pd.DataFrame(
data={

    'Count': [ len(F),
               len(M)  
             ],
    
    'Mean': [round(stat.mean(F), 2),
             round(stat.mean(M), 2)
            ],
    

    'StdDev':[round(stat.stdev(F), 3),
              round(stat.stdev(M), 3)
            ],
    
     },
    
    index=['F', 'M']
)

summary_of_swim_the_lake
# Out:
#    Count     Mean   StdDev
# F     30  1208.80  215.473
# M     23  1140.57  214.722

# %%
def sol80b():
    n_female = 30
    n_male = 23
    
    y_bar_female = 1208.80
    y_bar_male = 1140.57
    
    s_female = 215.47
    s_male = 214.722

    df = 47

    SE = sqrt ((s_female ** 2 / n_female) + (s_male ** 2 / n_male) )
    
    observed_diff = y_bar_female - y_bar_male
    tcritical = t.ppf(0.975, df)

    print(f"observed_diff: {observed_diff:.2f}")
    print(f"SE: {SE:.2f}")
    print (f"tcritical: {tcritical:.2f}")
    print(f"95% CI: ({(observed_diff-SE*tcritical):.2f}, {(observed_diff+SE*tcritical):.2f})")

sol80b()
# Out:
# observed_diff: 68.23
# SE: 59.60
# tcritical: 2.01
# 95% CI: (-51.67, 188.13)

# %% [markdown]
# **80(b) answer**
#
# The confidence interval is (-51.67, 188.13).  I am 95% confident that the mean crossing time of female is 51.67 less and 188.13 more than the mean time for male to cross the Lake Ontario. However, the CI still includes 0, and we may lack of evidence to conclude which group is faster.

# %% [markdown]
# **Answer to 80(c)**
#
# The repeated crossing by the swimmer who had crossed the lake before <font color="red">may change our assumptions about</font> the randomization condition.
#
# <font color="red">In the extreme, if all the data in a group come from a single swimmer crossing repetitively, we lose the randomization condition.</font>
#
# <font color="red">Furthermore, a repeating swimmer may achieve better performance due to familiarity with the game (therefore we are facing a mixed-model problem).</font>
