# %%
# %pwd
# Out:
# 'C:\\Users\\sc522\\PROJECTS\\STAT\\IS5\\code\\ch02'

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %%
file_name = "../../dataset/ch02/titanic.txt"

# %%
titanic = pd.read_csv(file_name, sep='\t')  # load tab (\t) separated values from the data file

# %%
titanic.head()  # a few rows on the top, including header
# Out:
#                             Name Survived      Boarded Class    MWC   Age  \
# 0             ABBING, Mr Anthony     Dead  Southampton     3    Man  42.0
# 1         ABBOTT, Mr Ernest Owen     Dead  Southampton  Crew    Man  21.0
# 2       ABBOTT, Mr Eugene Joseph     Dead  Southampton     3  Child  14.0
# 3     ABBOTT, Mr Rossmore Edward     Dead  Southampton     3    Man  16.0
# 4  ABBOTT, Mrs Rhoda Mary 'Rosa'    Alive  Southampton     3  Woman  39.0
#
#   Adut_or_Chld     Sex   Paid Ticket_No Boat_or_Body                    Job  \
# 0        Adult    Male   7.55      5547          NaN             Blacksmith
# 1        Adult    Male    NaN       NaN          NaN  Lounge Pantry Steward
# 2        Child    Male  20.25    CA2673          NaN                Scholar
# 3        Adult    Male  20.25    CA2673        [190]               Jeweller
# 4        Adult  Female  20.25    CA2673            A                    NaN
#
#             Class_Dept Class_Full
# 0  3rd Class Passenger          3
# 1     Victualling Crew          V
# 2  3rd Class Passenger          3
# 3  3rd Class Passenger          3
# 4  3rd Class Passenger          3

# %%
print(f"Sample size: {len(titanic)}")  # f-string and built-in len function for length (number of rows)
# Out:
# Sample size: 2208

# %%
titanic["Class"].value_counts()  # Frequency Table (absolute)
# Out:
# Crew    889
# 3       710
# 1       324
# 2       285
# Name: Class, dtype: int64

# %%
titanic.Class.value_counts(normalize=True)  # Frequency Table (relative)
# Out:
# Crew    0.402627
# 3       0.321558
# 1       0.146739
# 2       0.129076
# Name: Class, dtype: float64

# %%
ticket_class = titanic.Class

# %%
print(ticket_class.dtype)
# Out:
# object

# %%
ticket_class = ticket_class.apply(str).astype('string')
print(ticket_class.dtype)
# Out:
# string

# %%
pd.crosstab(index=ticket_class, columns="count")  # pandas cross tabulation
# Out:
# col_0  count
# Class
# 1        324
# 2        285
# 3        710
# Crew     889

# %%
titanic.groupby(['Class'])['Class'].count()  # group by the "Class" column, extract only that column, and then count
# Out:
# Class
# 1       324
# 2       285
# 3       710
# Crew    889
# Name: Class, dtype: int64

# %%
ticket_class.value_counts(ascending=True).plot(kind='bar')  # pandas plot value_counts
# Out:
# <Axes: >

# %%
ticket_class.value_counts(ascending=True).plot(kind='pie')  # pandas generate pie plot
# Out:
# <Axes: ylabel='Class'>

# %%
import matplotlib as mpl
print(mpl.__version__)
import matplotlib.pyplot as plt
# Out:
# 3.7.1

# %%
survivors = titanic.Survived[titanic.Survived == 'Alive'].count()  # number of survivors
fig, axes = plt.subplots(5, 5, figsize=(8, 8))  # a plot grid of 5x5
for r in range(5):
    for c in range(5):
        if (r, c) == (3, 1):
            # hide the real data
            titanic[titanic.Survived=='Alive']['Class'].value_counts().sort_index().plot(kind='pie', ax=axes[r, c])
        else:
            # simulated random sample
            ticket_class.sample(n=survivors).value_counts().sort_index().plot(kind='pie', ax=axes[r, c])

# %%
plt.hist(titanic['Class'].sort_values())  # pyplot histogram, as an alternative
# Out:
# (array([324.,   0.,   0., 285.,   0.,   0., 710.,   0.,   0., 889.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)
